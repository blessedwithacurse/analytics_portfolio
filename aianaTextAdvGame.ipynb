# %%
# Text Adventure Game Based on 'Life is Strange 1' video game

# %%
# this game has several outcomes

def decision_making(): #first decision of a user
    print("START")
    first_option = '1. Take the paper with you without telling anyone'
    second_option = '2. Try to talk to Max after class.'
    
    print("""You enter the class and proceed to your desk. You lay your head on the table to take a nap since you had trouble falling asleep last night and then you see the small piece of paper under your table. The paper says: "Hey, Max. I have an interesting video of you from the last night. If you  don't want annyone to see it, come to see me at the station near the academy at 7 P.M.\n""")
    print("You know Max, she sits right in front of you but she never really liked you, just like anyone else, because you are a weirdo.\n")
    print("What are your next steps: \n", first_option, "\n" ,second_option)
    
    user_decision = input(prompt = "Your choice. Enter a number only: \n");
    
    while True:
        if(user_decision == str(1)):
            decision_1_outcome_1()
        elif(user_decision == str(2)):
            decision_2_outcome_1()
        else:
            print("Please, enter only integers like 1 or 2!")
        user_decision = input(prompt = "Your choice. Enter a number only: \n");
        
def decision_1_outcome_1(): #the outcome of the first choice in decision_making() function
    first_option = '1. You will interrupt them asking what is going on.'
    second_option = '2. You again will take photo of them and will head back to the academy by yourself to talk to the director and show him all the evidences proving that your classmate is in danger.'

    print("You are ready to go home but when leaving the building, you saw a strange looking man talking to Max near the station. She was very uncomfortable talking to him. You started to realize that something serious is going on.")
    print("What are your next steps: \n", first_option, "\n" ,second_option)
    
    user_decision = input(prompt = "Your choice: ")
        
    while True:
        if(user_decision == str(1)):
            decision_1_outcome_interrupt()
        elif(user_decision == str(2)):
            decision_1_outcome_talk_to_dir()
        else:
            print("Please, enter only integers like 1 or 2!")
        user_decision = input(prompt = "Your choice. Enter a number only: \n");
        
def decision_1_outcome_talk_to_dir(): #the outcome of the second option in decision_1_outcome_1() function
    print("You come to the  school director's office and try to explain everything. She asks why I came to her without Max and that it all does not make any sense. After that, you decide that its not your business anyway and Maxine was never nice to you and even bullied so you decide to just leave.")
    decision_2_outcome_ignore_the_call()
        
def decision_1_outcome_interrupt(): #the outcome of the first option in decision_1_outcome_1() function
    
    first_option = '1. I know about the video. I am here to help you'
    second_option = '2. I know about the video. You deserved it!'

    print("You come closer to them and ask what is going. The man seems to be very annoyed by your presence and leave without saying a word. Max is almost crying  but anyway try to look at you like she always did: 'Why are you here???' ")
    
    print("Your answer: \n", first_option, "\n" ,second_option)
    
    user_decision = input(prompt = "Your choice: ")
    while True:
        if(user_decision == str(1)):
            decision_1_outcome_help()
        elif(user_decision == str(2)):
            decision_1_outcome_leave()
        else:
            print("Please, enter only integers!")
    user_decision = input(prompt = "Your choice. Enter a number only: \n");

def decision_1_outcome_leave():
    
    print("She screams at you saying how dare you to say such things to her. She said that you better not to come to her to try to talk to and then just ran away")
    decision_2_outcome_calm_down()
    
def decision_1_outcome_help():
    first_option = '1. You will suggest her to go to the police.'
    second_option = '2. You will ask her to calm down and wait.'
    
    print("She becomes furious after hearing that and wants you to answer how do you know about the video. You show her the paper. After seeing it her face changed. She asks how you can help her.")
    
    print("What will you choose?: \n", first_option, "\n" ,second_option)
    user_decision = input(prompt = "Your choice: ")
    
    while True:
        if(user_decision == str(1)):
            decision_2_outcome_police()
        elif(user_decision == str(2)):
            decision_2_outcome_calm_down()
        else:
            print("Please, enter only integers!")
        user_decision = input(prompt = "Your choice. Enter a number only: \n");

def decision_2_outcome_1(): 
    first_option = '1. You will suggest her to go to the police.'
    second_option = '2. You will ask her to calm down and wait.'
    
    print("After class you stoped Max and asked her for 1 minute talk. She was looking very anxious and stressed. You ask her about the paper and show it to her. After seeing that she starts crying. You comfort her and she tells you the truth about the party she was in. She said she drank a little but not much but than a man offered her a drink. After that she does not remember anything. The next day she received a video of herself doing things she does not remember doing. The man asks her for a huge amount of money to delete it but if not everyone will see it. Max explained that she does not have so much money and she does not know what to do since she can't tell it to her parents. She seemed hopeless.")
    print("What are your next steps: \n", first_option, "\n" ,second_option)
    
    user_decision = input(prompt = "Your choice: ")
    
    while True:
        if(user_decision == str(1)):
            decision_2_outcome_police()
        elif(user_decision == str(2)):
            decision_2_outcome_calm_down()
        else:
            print("Please, enter only integers!")
        user_decision = input(prompt = "Your choice. Enter a number only: \n");
        
def decision_2_outcome_police():
    print("You and Max go there and explain all the situation. After some time of investigation the problem is resolved and now she consideres you as a friend :)")

def decision_2_outcome_calm_down(): # outcome of saying calm down
    first_option = '1. Ignore it and continue to sleep since you have a quiz tomorrow'
    second_option = '2. Answer'
    print("Later, at about 11 PM you see a call from Max.")
    
    print("What would you do?: \n", first_option, "\n" ,second_option)
    
    user_decision = input(prompt = "Enter numbers only: ")
    
    while True:
        if(user_decision == str(1)):
            decision_2_outcome_ignore_the_call()
        elif(user_decision == str(2)):
            decision_2_outcome_answer()
        else:
            print("Please, enter only integers!")
        user_decision = input(prompt = "Your choice. Enter a number only: \n");

def decision_2_outcome_answer(): # outcome of answering the call
    print("She apologizes for being rude to you all the time and asks you to come to some place since she really needs someone by her side. You end up being good friends. Congrats!")

def decision_2_outcome_ignore_the_call(): # outcome of not answering the call
    print("The next day you enter the class but can't find Max. After a few minutes the teacher comes in and anounces to everyone that Maxine Caulfield has commited suicide at around midnight. You just sit and can't move.")
    fail()
    
def fail(): #fail
    print("\nYou couldn't save her == You failed")
    
decision_making()
# Out:
# START
# You enter the class and proceed to your desk. You lay your head on the table to take a nap since you had trouble falling asleep last night and then you see the small piece of paper under your table. The paper says: "Hey, Max. I have an interesting video of you from the last night. If you  don't want annyone to see it, come to see me at the station near the academy at 7 P.M.
#
# You know Max, she sits right in front of you but she never really liked you, just like anyone else, because you are a weirdo.
#
# What are your next steps:
#  1. Take the paper with you without telling anyone
#  2. Try to talk to Max after class.
# Your choice. Enter a number only:
# 1
# You are ready to go home but when leaving the building, you saw a strange looking man talking to Max near the station. She was very uncomfortable talking to him. You started to realize that something serious is going on.
# What are your next steps:
#  1. You will interrupt them asking what is going on.
# ...
